# %%
import os

from dotenv import load_dotenv
import gspread

load_dotenv()
# Out:
# True

# %%
gc = gspread.service_account(
    scopes=[
        "https://spreadsheets.google.com/feeds",
        "https://www.googleapis.com/auth/drive",
    ]
)

# %%
gc

# %%
# Open a sheet from a spreadsheet in one go
wks = gc.open_by_key(os.getenv("LEAGUE_SHEET_KEY"))

# %%
wks.worksheets()
# Out:
# [<Worksheet 'Difficulty' id:0>,
#  <Worksheet 'Scoring' id:316359929>,
#  <Worksheet 'Teams' id:492741153>,
#  <Worksheet 'Climbers' id:897073945>]

# %%
import pandas as pd

# %%
teams = pd.DataFrame.from_records(wks.worksheet('Teams').get_all_records(), index='id')
teams
# Out:
#                            Team Name Team Emoji
# id
# 1                   Team head empty           🤠
# 2              Power Bar Racing Team        ⚡️🍫
# 3               Climb More Take Less
# 4                           Teamtop           🏕
# 5                  Ain't Nobody Beta  ¯\_(ツ)_/¯
# 6                    Supple dumpers           🫠
# 7   Leave the rope, take the cannoli         ❄️
# 8        Boulder? I hardly know ‘er!
# 10        The New York Stock Brokers          📈

# %%
climbers = pd.DataFrame.from_records(wks.worksheet('Climbers').get_all_records(), index='id')
climbers
# Out:
#                       name                              email  grade team
# id
#                Alan Hajder               alanhajder@gmail.com  5.10+    1
#             Izabela Hajder                 hajder@aclanyc.com  5.10-    1
#                  Matt Keim              mattkeim009@gmail.com  5.10+    1
#              Carlos Garcia            blackstone264@gmail.com    5.1    1
#             Matt Cianfrani            Matt@cianfranifilms.com   5.11    2
#             Amanda Jenkins               Amandajnyc@gmail.com  5.10+    2
#               Daria Huxley              dariahuxley@gmail.com    5.1    2
#             Jackson Jarvis         jacksonjarvis.dp@gmail.com    5.1    2
#               Zsolt Bendel               zsbendel@hotmail.com  5.10+    3
#            Adrienne Dalena          Asphyxiation143@gmail.com  5.10-    3
#              Jacob Willner              jakewillner@gmail.com    5.1    4
#                   Grayson              Grayson.hild@gmail.com   5.9+    4
#     Sebastian Jungschaffer             jungschaffer@gmail.com    5.1    5
#           Dennis Pomaquero         Pomaquero.dennis@gmail.com    5.1    5
#                  Jihye Hah                jihye.hah@gmail.com    5.1    5
#             Katia Sidlosca              katsidlosca@gmail.com    5.1    5
#        Christopher Randall   christopherjoelrandall@gmail.com  5.10+    6
#              Dakota Bowman           Dakotabowman11@yahoo.com  5.10+    6
#                   Loganyu                  yu.logan@gmail.com  5.10-    7
#                 Jess Jones              Jess.jonesr@gmail.com    5.7    7
#                     Di Tan                Difengtan@gmail.com    5.1    7
#           Alex Dotterweich          alexdotterweich@gmail.com    5.1    7
#              Liam Mcelheny                 Liammcel@gmail.com   5.11    3
#                Clara Smith            clara@smithsaltzman.com   5.9+    3
#              Zack Drescher             Hello@zackdrescher.com    5.9   10
#           Castina Bombardo              cbombardo13@gmail.com  5.10-   10
#               Steven miner           Info@stevenjohnminer.com  5.11-   10
#               Jono Pivovar         jonathan.pivovar@gmail.com    5.1   10
#       Victoria fitzgerald                vfitzger21@gmail.com  5.10+
#       Stephanie Rodriguez   Stephanierodriguez16481@gmail.com   5.9+    4
#                 Row Kiefer          Rebecca27kiefer@gmail.com    5.9    4
#            Luciana Torres            Luciana.torres@gmail.com  5.10-    6
#               Jiayin Zhang                     Jz4021@nyu.edu    5.9    6

# %%
climbers.team.value_counts()
# Out:
# 1     4
# 2     4
# 3     4
# 4     4
# 5     4
# 6     4
# 7     4
# 10    4
#       1
# Name: team, dtype: int64

# %%
n_f = climbers.team == ''
no_team = climbers[n_f]
team = climbers[~n_f]

# %%
no_team.email.isin(team.email)
# Out:
# id
#     False
# Name: email, dtype: bool
