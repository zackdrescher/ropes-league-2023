# %%
import os

if os.getcwd().endswith("notebooks"):
    os.chdir("..")

# %%
import ropes_league

# %%
data = ropes_league.LeagueData.from_env()

# %%
scores = data.season_scores()

# %%
scores
# Out:
#      team_id  climber_id                              email grade_1    rope_1  \
# 0          4          14  Stephanierodriguez16481@gmail.com    5.10  Top Rope
# 1         10          31         jonathan.pivovar@gmail.com    5.11  Top Rope
# 2          4          15          Rebecca27kiefer@gmail.com   5.10-  Top Rope
# 3         10          29              Cbombardo13@gmail.com   5.10-  Top Rope
# 4          7          26               Difengtan@gmail.com     5.10  Top Rope
# ..       ...         ...                                ...     ...       ...
# 152        5          18                jihye.hah@gmail.com   5.10+  Top Rope
# 153        5          17         Pomaquero.dennis@gmail.com   5.10+  Top Rope
# 154        1           1                 hajder@aclanyc.com   5.10-  Top Rope
# 155        7          24                 yu.logan@gmail.com    5.11  Top Rope
# 156        7          25              Jess.jonesr@gmail.com     5.9  Top Rope
#
# ...
